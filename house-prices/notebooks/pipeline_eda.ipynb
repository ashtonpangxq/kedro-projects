# %%
# Data Inspection
train = catalog.load('train')
test = catalog.load('test')
# Out:
# [07/20/22 23:17:19] INFO     Loading data from 'train' (CSVDataSet)...                          ]8;id=15145;file://C:\Users\AshtonPang\anaconda3\envs\kedro-env\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=927770;file://C:\Users\AshtonPang\anaconda3\envs\kedro-env\lib\site-packages\kedro\io\data_catalog.py#343\343]8;;\
#                     INFO     Loading data from 'test' (CSVDataSet)...                           ]8;id=74351;file://C:\Users\AshtonPang\anaconda3\envs\kedro-env\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=39903;file://C:\Users\AshtonPang\anaconda3\envs\kedro-env\lib\site-packages\kedro\io\data_catalog.py#343\343]8;;\

# %%
train.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Id</th>
#       <th>MSSubClass</th>
#       <th>MSZoning</th>
#       <th>LotFrontage</th>
#       <th>LotArea</th>
#       <th>Street</th>
#       <th>Alley</th>
#       <th>LotShape</th>
#       <th>LandContour</th>
#       <th>Utilities</th>
#       <th>...</th>
#       <th>PoolArea</th>
#       <th>PoolQC</th>
#       <th>Fence</th>
#       <th>MiscFeature</th>
#       <th>MiscVal</th>
#       <th>MoSold</th>
#       <th>YrSold</th>
#       <th>SaleType</th>
#       <th>SaleCondition</th>
#       <th>SalePrice</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
# ...

# %%
test.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Id</th>
#       <th>MSSubClass</th>
#       <th>MSZoning</th>
#       <th>LotFrontage</th>
#       <th>LotArea</th>
#       <th>Street</th>
#       <th>Alley</th>
#       <th>LotShape</th>
#       <th>LandContour</th>
#       <th>Utilities</th>
#       <th>...</th>
#       <th>ScreenPorch</th>
#       <th>PoolArea</th>
#       <th>PoolQC</th>
#       <th>Fence</th>
#       <th>MiscFeature</th>
#       <th>MiscVal</th>
#       <th>MoSold</th>
#       <th>YrSold</th>
#       <th>SaleType</th>
#       <th>SaleCondition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1461</td>
# ...

# %%
# Inspect preprocessed data
preprocessed_train = catalog.load('preprocessed_train')
preprocessed_test = catalog.load('preprocessed_test')
# Out:
# [07/20/22 23:18:55] INFO     Loading data from 'preprocessed_train' (ParquetDataSet)...         ]8;id=524450;file://C:\Users\AshtonPang\anaconda3\envs\kedro-env\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=554449;file://C:\Users\AshtonPang\anaconda3\envs\kedro-env\lib\site-packages\kedro\io\data_catalog.py#343\343]8;;\
# [07/20/22 23:18:56] INFO     Loading data from 'preprocessed_test' (ParquetDataSet)...          ]8;id=925547;file://C:\Users\AshtonPang\anaconda3\envs\kedro-env\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=465619;file://C:\Users\AshtonPang\anaconda3\envs\kedro-env\lib\site-packages\kedro\io\data_catalog.py#343\343]8;;\

# %%
preprocessed_train.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MSSubClass</th>
#       <th>MSZoning</th>
#       <th>LotArea</th>
#       <th>Street</th>
#       <th>Alley</th>
#       <th>LotShape</th>
#       <th>LandContour</th>
#       <th>Utilities</th>
#       <th>LotConfig</th>
#       <th>LandSlope</th>
#       <th>...</th>
#       <th>PoolArea</th>
#       <th>PoolQC</th>
#       <th>Fence</th>
#       <th>MiscFeature</th>
#       <th>MiscVal</th>
#       <th>MoSold</th>
#       <th>YrSold</th>
#       <th>SaleType</th>
#       <th>SaleCondition</th>
#       <th>SalePrice</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>60</td>
# ...

# %%
preprocessed_test.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MSSubClass</th>
#       <th>MSZoning</th>
#       <th>LotArea</th>
#       <th>Street</th>
#       <th>Alley</th>
#       <th>LotShape</th>
#       <th>LandContour</th>
#       <th>Utilities</th>
#       <th>LotConfig</th>
#       <th>LandSlope</th>
#       <th>...</th>
#       <th>ScreenPorch</th>
#       <th>PoolArea</th>
#       <th>PoolQC</th>
#       <th>Fence</th>
#       <th>MiscFeature</th>
#       <th>MiscVal</th>
#       <th>MoSold</th>
#       <th>YrSold</th>
#       <th>SaleType</th>
#       <th>SaleCondition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>20</td>
# ...

# %%
catalog.list()
# Out:
# [
#     'train',
#     'test',
#     'preprocessed_train',
#     'preprocessed_test',
#     'train_evaluation.linear_regression.regressor',
#     'train_evaluation.random_forest.regressor',
#     'train_evaluation.r2_score_linear_regression',
#     'train_evaluation.r2_score_random_forest',
#     'train_evaluation.hyperparams_linear_regression',
#     'train_evaluation.hyperparams_random_forest',
#     'parameters',
#     'params:split_options',
#     'params:split_options.test_size',
#     'params:split_options.random_state',
#     'params:split_options.target',
#     'params:train_evaluation',
#     'params:train_evaluation.model_options',
#     'params:train_evaluation.model_options.linear_regression',
#     'params:train_evaluation.model_options.linear_regression.module',
#     'params:train_evaluation.model_options.linear_regression.class',
#     'params:train_evaluation.model_options.linear_regression.kwargs',
# ...

# %%
# Hyperparameters for Linear Regression
lr_params = catalog.load('params:train_evaluation.model_options.linear_regression.kwargs')
lr_params
# Out:
# [07/20/22 23:21:43] INFO     Loading data from                                                  ]8;id=16680;file://C:\Users\AshtonPang\anaconda3\envs\kedro-env\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=128805;file://C:\Users\AshtonPang\anaconda3\envs\kedro-env\lib\site-packages\kedro\io\data_catalog.py#343\343]8;;\
#                              'params:train_evaluation.model_options.linear_regression.kwargs'
#                              (MemoryDataSet)...
# {'fit_intercept': True, 'copy_X': True, 'positive': False}

# %%
# Hyperparameters for Random Forest
rf_params = catalog.load('params:train_evaluation.model_options.random_forest.kwargs')
rf_params
# Out:
# [07/20/22 23:22:02] INFO     Loading data from                                                  ]8;id=619155;file://C:\Users\AshtonPang\anaconda3\envs\kedro-env\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=719300;file://C:\Users\AshtonPang\anaconda3\envs\kedro-env\lib\site-packages\kedro\io\data_catalog.py#343\343]8;;\
#                              'params:train_evaluation.model_options.random_forest.kwargs'
#                              (MemoryDataSet)...
# {
#     'n_estimators': 100,
#     'criterion': 'squared_error',
#     'min_samples_split': 2,
#     'min_samples_leaf': 1,
#     'min_weight_fraction_leaf': 0,
#     'max_features': 'auto',
#     'min_impurity_decrease': 0,
#     'bootstrap': True,
#     'oob_score': False,
#     'verbose': 0,
#     'warm_start': False,
#     'ccp_alpha': 0
# }
